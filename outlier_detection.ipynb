# %%
from stock_data import StockDataStore, DailyIndicatorStore

tsla_stock = StockDataStore("TSLA")

# Load a CSV file and do all the pre-processing
tsla_stock.load_from_csv("TSLA_5Y.csv")

# Cleaned up DataFrame with flagged/removed outliers, null data handling, etc.
print(tsla_stock.data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/project/school/concordia/COMP-333/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'outlier_desc'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 6
#       3 tsla_stock = StockDataStore("TSLA")
#       5 # Load a CSV file and do all the pre-processing
# ----> 6 tsla_stock.load_from_csv("TSLA_5Y.csv")
#       8 # Cleaned up DataFrame with flagged/removed outliers, null data handling, etc.
#       9 print(tsla_stock.data)
#
# File ~/project/school/concordia/COMP-333/P1_40314968_CoulombeMorency_Julien/stock_data.py:38, in StockDataStore.load_from_csv(self, file_path)
#      35 for col in ["Open", "High", "Low", "Close"]:
#      36     self._convert_currency_to_float(col)
# ---> 38 self._preprocess_data()
#      40 self._store = self._raw.copy()
#
# File ~/project/school/concordia/COMP-333/P1_40314968_CoulombeMorency_Julien/stock_data.py:44, in StockDataStore._preprocess_data(self)
#      42 def _preprocess_data(self):
#      43     self._add_simple_features()
# ---> 44     self._detect_and_handle_outliers()
#
# File ~/project/school/concordia/COMP-333/P1_40314968_CoulombeMorency_Julien/stock_data.py:67, in StockDataStore._detect_and_handle_outliers(self)
#      64     raise ValueError("Dataframe is empty. Load data first.")
#      66 self._raw["is_outlier"] = False
# ---> 67 self._raw["outlier_desc"].astype(str)
#      69 # 1) Make sure data is consistent: Open|High|Close|Low -> Making sure no impossible values exist
#      70 self._detect_inconsistencies()
#
# File ~/project/school/concordia/COMP-333/.venv/lib/python3.13/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File ~/project/school/concordia/COMP-333/.venv/lib/python3.13/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'outlier_desc'

# %%
indicators = DailyIndicatorStore(tsla_stock)

print(indicators.data)
# Out:
#      calculation_date ticker      sma_20      sma_50     rsi_14       macd  \
# 0          2020-11-02   TSLA  133.500000  133.500000   0.000000   0.000000
# 1          2020-11-03   TSLA  137.400000  137.400000   0.000000   0.622222
# 2          2020-11-04   TSLA  138.376667  138.376667  88.189250   1.025248
# 3          2020-11-05   TSLA  140.290000  140.290000  93.241039   1.784027
# 4          2020-11-06   TSLA  140.896000  140.896000  76.489691   2.141998
# ...               ...    ...         ...         ...        ...        ...
# 1249       2025-10-24   TSLA  439.712000  396.440000  52.967774  10.791035
# 1250       2025-10-27   TSLA  440.313000  398.776800  59.326749  11.109596
# 1251       2025-10-28   TSLA  441.180000  401.376600  61.748208  11.881122
# 1252       2025-10-29   TSLA  442.019500  403.903600  62.035623  12.426778
# 1253       2025-10-30   TSLA  441.051500  406.119400  52.551943  11.004750
#
#       bollinger_upper  bollinger_lower  volatility_20d  rsi_14_norm  \
# 0          133.500000       133.500000        0.000000     0.000000
# 1          145.200000       129.600000        0.450708     0.000000
# 2          145.318642       131.434691        0.452911     0.881893
# 3          149.238374       131.341626        0.423370     0.932410
# 4          149.258685       132.533315        0.460110     0.764897
# ...               ...              ...             ...          ...
# 1249       455.462401       423.961599        0.511620     0.529678
# 1250       457.011333       423.614667        0.514069     0.593267
# 1251       460.049454       422.310546        0.515823     0.617482
# 1252       462.837586       421.201414        0.515930     0.620356
# 1253       460.275113       421.827887        0.537945     0.525519
#
#       sma_20_ratio  sma_50_ratio  macd_pct    bb_pos  volatility_20d_z
# 0         0.000000      0.000000  0.000000       NaN         -3.251769
# 1         0.028384      0.028384  0.004404  0.500000         -0.660703
# 2         0.014116      0.014116  0.007306  0.281380         -0.648035
# 3         0.040915      0.040915  0.012217  0.641457         -0.817864
# 4         0.017204      0.017204  0.014946  0.289859         -0.606650
# ...            ...           ...       ...       ...               ...
# 1249     -0.013627      0.094037  0.024880 -0.380435         -0.310525
# 1250      0.027496      0.134519  0.024556  0.725042         -0.296442
# 1251      0.043905      0.147426  0.025798  1.026527         -0.286363
# 1252      0.044094      0.142624  0.026926  0.936229         -0.285744
# 1253     -0.002157      0.083671  0.025005 -0.049496         -0.159187
#
# [1254 rows x 15 columns]
